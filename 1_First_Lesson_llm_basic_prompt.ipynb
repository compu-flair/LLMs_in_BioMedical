# %%
import os

# %%
from dotenv import load_dotenv

# %%
load_dotenv(".env")
openai_api_key = os.getenv("openai_api_key")

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(openai_api_key=openai_api_key)

# %%
llm.invoke("tell me a joke.")

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("user", "I would like to understant {user_input}. Can you tell me more about it?")
    ]
)

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
out_parser = StrOutputParser()

# %%
chain = prompt | llm | out_parser

# %%
ai_message = chain.invoke({"user_input":"earth"})

# %%
ai_message
# Out:
# 'Certainly! Earth is the third planet from the Sun and is the only known planet to support life. It is approximately 4.5 billion years old and has a diameter of about 12,742 kilometers (7,918 miles). Earth is part of the solar system and is located in the Milky Way galaxy.\n\nHere are some key features and characteristics of Earth:\n\n1. Atmosphere: Earth has a unique atmosphere composed of various gases, with nitrogen making up about 78% and oxygen about 21%. The atmosphere protects the planet from harmful solar radiation and helps regulate temperature.\n\n2. Geology: Earth\'s outer layer is divided into tectonic plates, which are in constant motion. This movement causes earthquakes, volcanic activity, and the formation of mountains and valleys.\n\n3. Hydrosphere: Earth is often called the "Blue Planet" because about 70% of its surface is covered in water. The oceans, rivers, lakes, and other bodies of water make up the hydrosphere, which plays a vital role in supporting life.\n\n4. Biosphere: Earth is teeming with life in various forms, from microorganisms to complex organisms like plants and animals. The biosphere refers to all the ecosystems on Earth where life exists.\n\n5. Climate: Earth experiences a range of climates due to factors like latitude, topography, and ocean currents. This leads to diverse weather patterns, including rainfall, snowfall, and temperature variations.\n\n6. Magnetic Field: Earth has a magnetic field generated by its core, which helps protect the planet from harmful solar winds and particles.\n\n7. Natural Resources: Earth provides various essential resources for humans, such as freshwater, minerals, fossil fuels, and renewable energy sources like wind and solar power.\n\n8. Seasons: Earth\'s axial tilt causes the planet to have seasons as it orbits the Sun. This leads to the cycle of spring, summer, autumn, and winter.\n\nUnderstanding Earth is a complex and fascinating subject, with many fields of study devoted to exploring its different aspects, including geology, meteorology, biology, and more.'

# %%
print(ai_message)
# Out:
# Certainly! Earth is the third planet from the Sun and is the only known planet to support life. It is approximately 4.5 billion years old and has a diameter of about 12,742 kilometers (7,918 miles). Earth is part of the solar system and is located in the Milky Way galaxy.
#
# Here are some key features and characteristics of Earth:
#
# 1. Atmosphere: Earth has a unique atmosphere composed of various gases, with nitrogen making up about 78% and oxygen about 21%. The atmosphere protects the planet from harmful solar radiation and helps regulate temperature.
#
# 2. Geology: Earth's outer layer is divided into tectonic plates, which are in constant motion. This movement causes earthquakes, volcanic activity, and the formation of mountains and valleys.
#
# 3. Hydrosphere: Earth is often called the "Blue Planet" because about 70% of its surface is covered in water. The oceans, rivers, lakes, and other bodies of water make up the hydrosphere, which plays a vital role in supporting life.
#
# 4. Biosphere: Earth is teeming with life in various forms, from microorganisms to complex organisms like plants and animals. The biosphere refers to all the ecosystems on Earth where life exists.
#
# 5. Climate: Earth experiences a range of climates due to factors like latitude, topography, and ocean currents. This leads to diverse weather patterns, including rainfall, snowfall, and temperature variations.
#
# 6. Magnetic Field: Earth has a magnetic field generated by its core, which helps protect the planet from harmful solar winds and particles.
#
# 7. Natural Resources: Earth provides various essential resources for humans, such as freshwater, minerals, fossil fuels, and renewable energy sources like wind and solar power.
#
# 8. Seasons: Earth's axial tilt causes the planet to have seasons as it orbits the Sun. This leads to the cycle of spring, summer, autumn, and winter.
#
# Understanding Earth is a complex and fascinating subject, with many fields of study devoted to exploring its different aspects, including geology, meteorology, biology, and more.
